# %%
import numpy as np  # type: ignore
import matplotlib.pyplot as plt  # type: ignore
from cedar.draw import putText

# Create a white image (500x500) and add text to it
zeros_image = np.ones((200, 200, 3), dtype=np.uint8) * 255
img = putText(zeros_image, "12你好，世界！‰", (0, 0))

plt.imshow(img)
plt.show()
